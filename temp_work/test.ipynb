# %% [markdown]
# Import Libraries

# %%
# Load Libraries
import gymnasium as gym
from gymnasium import Env, spaces
import pandas as pd
import numpy as np
from stable_baselines3 import PPO
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.callbacks import EvalCallback
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.vec_env import VecNormalize
from scipy.special import expit
import os

# %% [markdown]
# Load Data

# %%
train_df = pd.read_csv("../datasets/train_split.csv")
val_df =  pd.read_csv("../datasets/val_split.csv")

# %%
train_df.head(5)
# Out:
#    Pickup Location  Request to Pickup  Hour of Day  Time of Day  \
# 0              197              670.0           21            3
# 1              225              128.0           23            3
# 2              137              366.0           16            0
# 3               26              700.0            2            3
# 4               85              320.0           22            3
#
#    Month of Year  Surge Pricing Indicator  DWF Reward Applied  \
# 0              3                        0                4.83
# 1              5                        0                0.00
# 2             11                        0                0.00
# 3              8                        0                4.92
# 4              0                        0                0.00
#
#    Historical Demand Forecast       RPI  incentive  fare_adjustment       DPI  \
# 0                    0.479649  0.065061   3.395189         0.126559  0.000000
# 1                    0.546620  0.972298   3.286800         0.029585  0.104209
# 2                    0.414232  0.209321   2.891493        -0.121712  0.000000
# 3                    0.106542  0.016135   0.602682         0.079705  0.007461
# 4                    0.470866  0.411112   0.270961         0.018889  0.021444
#
#          CR  Base Fare
# 0  0.625502       7.96
# 1  0.402431      16.38
# 2  0.581822      18.34
# 3  0.635127      15.10
# 4  0.536379       8.11

# %% [markdown]
# Define RL Environment

# %%
class RideHailingEnv(Env):
    def __init__(self, df):
        super(RideHailingEnv, self).__init__()
        self.df = df.reset_index(drop=True)
        self.current_idx = 0
        self.episode_limit = 1000
        self.episode_start = 0

        self.observation_space = spaces.Box(low=0, high=1, shape=(8,), dtype=np.float32)
        self.action_space = spaces.Box(
            low=np.array([-0.15, 0.0]),
            high=np.array([0.15, 5.0]),
            dtype=np.float32
        )

    def reset(self, *, seed=None, options=None):
        super().reset(seed=seed)
        self.current_idx = np.random.randint(0, len(self.df) - self.episode_limit)
        self.episode_start = self.current_idx
        return self._get_observation(), {}

    def step(self, action):
        if self.current_idx >= len(self.df) - 1 or (self.current_idx - self.episode_start >= self.episode_limit):
            obs = self._get_observation()
            done = True
            reward = 0.0
            self.episode_start = self.current_idx + 1
            return obs, reward, done, False, {"CR": 0.5}

        row = self.df.iloc[self.current_idx]
        fare_adjustment, rider_incentive = np.round(action, 2)
        t_i = row['Request to Pickup']
        base_fare = row.get('Base Fare', 10.0)

        # --- Behavior-based cancellation modeling
        rank_percentile = (self.df['Request to Pickup'] < t_i).sum() / len(self.df)
        epsilon = np.random.normal(loc=0.0, scale=0.02)

        RPI = np.clip(1.0 - rank_percentile + epsilon, 0.0, 1.0)
        delta = 0.2 * base_fare
        DPI = np.clip((rider_incentive + fare_adjustment * base_fare) / (t_i + 1e-5) + epsilon, 0.0, 1.0)

        cr_input = 0.75 * rank_percentile - 1.1 * RPI - 0.9 * DPI
        CR = 1.0 / (1.0 + np.exp(-cr_input))
        ride_completed = CR < 0.5

        reward = 4.0 if ride_completed else -4.0   # Increase absolute signal
        cost_penalty = (rider_incentive + abs(fare_adjustment) * delta) / (base_fare + 5)
        reward -= 0.8 * cost_penalty               # Reduce penalty scaling

        if rider_incentive > 3.0 or abs(fare_adjustment) > 0.12:
            reward -= 0.3                          # Softer soft-penalty

        reward = np.clip(reward, -8.0, 6.0)        # Wider positive range

        self.current_idx += 1
        done = False
        obs = self._get_observation()
        return obs, reward, done, False, {"CR": CR}

    def _get_observation(self):
        if self.current_idx >= len(self.df):
            return np.zeros(self.observation_space.shape, dtype=np.float32)
        row = self.df.iloc[self.current_idx]
        return np.array([
            row['Pickup Location'],
            row['Request to Pickup'],
            row['Time of Day'],
            row['Month of Year'],
            row['RPI'],
            row['DPI'],
            row['CR'],
            row['Historical Demand Forecast']
        ], dtype=np.float32)

# %% [markdown]
# Model Performance Monitoring

# %%
# Ensure logs directory exists
os.makedirs("logs", exist_ok=True)


# Training env
train_env = DummyVecEnv([lambda: RideHailingEnv(train_df)])
train_env = VecNormalize(train_env, norm_obs=True, norm_reward=True)

# Validation env
val_env = DummyVecEnv([lambda: RideHailingEnv(val_df)])
val_env = VecNormalize(val_env, training=False, norm_obs=True, norm_reward=False)

# Evaluation callback
eval_callback = EvalCallback(
    val_env,
    best_model_save_path="./logs/",
    log_path="./logs/",
    eval_freq=5000,
    deterministic=True,
    render=False
)

# %% [markdown]
# Model Training

# %%
from stable_baselines3 import PPO

model = PPO(
    "MlpPolicy",
    train_env,
    tensorboard_log="./ppo_tensorboard_logs/",
    learning_rate=5e-4,
    n_steps=2048,
    batch_size=256,
    gamma=0.96,
    gae_lambda=0.95,
    clip_range=0.4,               # softer clipping
    ent_coef=0.03,                # boost exploration
    vf_coef=0.4,
    max_grad_norm=0.5,            # prevent exploding grads
    policy_kwargs=dict(net_arch=[64, 64]),
    verbose=1,
    device="cuda"
)

model.learn(total_timesteps=99000, callback=eval_callback)
model.save("../models/dwf_rl_pricing_model_v6")

# Save normalization stats for later evaluation use
train_env.save("../models/vecnormalize.pkl")
# Out:
# Using cuda device
# Logging to ./ppo_tensorboard_logs/PPO_3
# c:\anaconda\envs\analysis\Lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# -----------------------------
# | time/              |      |
# |    fps             | 368  |
# |    iterations      | 1    |
# |    time_elapsed    | 5    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 347         |
# |    iterations           | 2           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.012952632 |
# |    clip_fraction        | 0.0126      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -2.85       |
# |    explained_variance   | -0.5        |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0111     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00425    |
# |    std                  | 1.01        |
# |    value_loss           | 0.317       |
# -----------------------------------------
# c:\anaconda\envs\analysis\Lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=5000, episode_reward=712.91 +/- 224.54
# Episode length: 1001.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1e+03       |
# |    mean_reward          | 713         |
# | time/                   |             |
# |    total_timesteps      | 5000        |
# | train/                  |             |
# |    approx_kl            | 0.018512893 |
# |    clip_fraction        | 0.0233      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -2.87       |
# |    explained_variance   | 0.0761      |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0553     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00615    |
# |    std                  | 1.02        |
# |    value_loss           | 0.0992      |
# -----------------------------------------
# New best mean reward!
# -----------------------------
# | time/              |      |
# |    fps             | 230  |
# |    iterations      | 3    |
# |    time_elapsed    | 26   |
# |    total_timesteps | 6144 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 249         |
# |    iterations           | 4           |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.011615744 |
# |    clip_fraction        | 0.0135      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -2.88       |
# |    explained_variance   | 0.114       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0422     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00674    |
# |    std                  | 1.02        |
# |    value_loss           | 0.123       |
# -----------------------------------------
# Eval num_timesteps=10000, episode_reward=575.16 +/- 194.55
# Episode length: 1001.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1e+03       |
# |    mean_reward          | 575         |
# | time/                   |             |
# |    total_timesteps      | 10000       |
# | train/                  |             |
# |    approx_kl            | 0.006162609 |
# |    clip_fraction        | 0.00522     |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -2.89       |
# |    explained_variance   | 0.0939      |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0445     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00384    |
# |    std                  | 1.03        |
# |    value_loss           | 0.103       |
# -----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 216   |
# |    iterations      | 5     |
# |    time_elapsed    | 47    |
# |    total_timesteps | 10240 |
# ------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 229        |
# |    iterations           | 6          |
# |    time_elapsed         | 53         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.02173796 |
# |    clip_fraction        | 0.0311     |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -2.89      |
# |    explained_variance   | 0.101      |
# |    learning_rate        | 0.0005     |
# |    loss                 | -0.0942    |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.0094    |
# |    std                  | 1.02       |
# |    value_loss           | 0.117      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 240         |
# |    iterations           | 7           |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.023540616 |
# |    clip_fraction        | 0.0361      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -2.89       |
# |    explained_variance   | 0.116       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0688     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0117     |
# |    std                  | 1.03        |
# |    value_loss           | 0.107       |
# -----------------------------------------
# Eval num_timesteps=15000, episode_reward=414.07 +/- 116.61
# Episode length: 1001.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1e+03       |
# |    mean_reward          | 414         |
# | time/                   |             |
# |    total_timesteps      | 15000       |
# | train/                  |             |
# |    approx_kl            | 0.022913273 |
# |    clip_fraction        | 0.0389      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -2.91       |
# |    explained_variance   | 0.115       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.05       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0106     |
# |    std                  | 1.04        |
# |    value_loss           | 0.11        |
# -----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 220   |
# |    iterations      | 8     |
# |    time_elapsed    | 74    |
# |    total_timesteps | 16384 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 228         |
# |    iterations           | 9           |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.017460966 |
# |    clip_fraction        | 0.024       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -2.92       |
# |    explained_variance   | 0.123       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0508     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00827    |
# |    std                  | 1.04        |
# |    value_loss           | 0.105       |
# -----------------------------------------
# Eval num_timesteps=20000, episode_reward=524.11 +/- 229.63
# Episode length: 1001.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1e+03       |
# |    mean_reward          | 524         |
# | time/                   |             |
# |    total_timesteps      | 20000       |
# | train/                  |             |
# |    approx_kl            | 0.019356938 |
# |    clip_fraction        | 0.0274      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -2.92       |
# |    explained_variance   | 0.111       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0617     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00895    |
# |    std                  | 1.04        |
# |    value_loss           | 0.1         |
# -----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 215   |
# |    iterations      | 10    |
# |    time_elapsed    | 95    |
# |    total_timesteps | 20480 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 222         |
# |    iterations           | 11          |
# |    time_elapsed         | 101         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.024823945 |
# |    clip_fraction        | 0.0362      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -2.93       |
# |    explained_variance   | 0.112       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.064      |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0102     |
# |    std                  | 1.05        |
# |    value_loss           | 0.0974      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 228         |
# |    iterations           | 12          |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.016407596 |
# |    clip_fraction        | 0.0218      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -2.95       |
# |    explained_variance   | 0.125       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0392     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00729    |
# |    std                  | 1.06        |
# |    value_loss           | 0.104       |
# -----------------------------------------
# Eval num_timesteps=25000, episode_reward=637.81 +/- 124.93
# Episode length: 1001.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1e+03       |
# |    mean_reward          | 638         |
# | time/                   |             |
# |    total_timesteps      | 25000       |
# | train/                  |             |
# |    approx_kl            | 0.008625837 |
# |    clip_fraction        | 0.00439     |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -2.97       |
# |    explained_variance   | 0.131       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0503     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00384    |
# |    std                  | 1.08        |
# |    value_loss           | 0.0765      |
# -----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 218   |
# |    iterations      | 13    |
# |    time_elapsed    | 121   |
# |    total_timesteps | 26624 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 224         |
# |    iterations           | 14          |
# |    time_elapsed         | 127         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.030042328 |
# |    clip_fraction        | 0.0674      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -2.99       |
# |    explained_variance   | 0.123       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0687     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0157     |
# |    std                  | 1.08        |
# |    value_loss           | 0.0942      |
# -----------------------------------------
# Eval num_timesteps=30000, episode_reward=424.18 +/- 202.53
# Episode length: 1001.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1e+03       |
# |    mean_reward          | 424         |
# | time/                   |             |
# |    total_timesteps      | 30000       |
# | train/                  |             |
# |    approx_kl            | 0.020562703 |
# |    clip_fraction        | 0.0449      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -3.02       |
# |    explained_variance   | 0.125       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0887     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0125     |
# |    std                  | 1.1         |
# |    value_loss           | 0.088       |
# -----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 215   |
# |    iterations      | 15    |
# |    time_elapsed    | 142   |
# |    total_timesteps | 30720 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 220         |
# |    iterations           | 16          |
# |    time_elapsed         | 148         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.023535565 |
# |    clip_fraction        | 0.0373      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -3.03       |
# |    explained_variance   | 0.117       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0797     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0124     |
# |    std                  | 1.1         |
# |    value_loss           | 0.0969      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 224         |
# |    iterations           | 17          |
# |    time_elapsed         | 154         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.021647606 |
# |    clip_fraction        | 0.044       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -3.03       |
# |    explained_variance   | 0.133       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0847     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0109     |
# |    std                  | 1.1         |
# |    value_loss           | 0.0943      |
# -----------------------------------------
# Eval num_timesteps=35000, episode_reward=503.79 +/- 127.20
# Episode length: 1001.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1e+03       |
# |    mean_reward          | 504         |
# | time/                   |             |
# |    total_timesteps      | 35000       |
# | train/                  |             |
# |    approx_kl            | 0.020524798 |
# |    clip_fraction        | 0.0289      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -3.05       |
# |    explained_variance   | 0.128       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0692     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0102     |
# |    std                  | 1.11        |
# |    value_loss           | 0.1         |
# -----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 217   |
# |    iterations      | 18    |
# |    time_elapsed    | 169   |
# |    total_timesteps | 36864 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 221         |
# |    iterations           | 19          |
# |    time_elapsed         | 175         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.009849935 |
# |    clip_fraction        | 0.0108      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -3.06       |
# |    explained_variance   | 0.13        |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0514     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00519    |
# |    std                  | 1.12        |
# |    value_loss           | 0.124       |
# -----------------------------------------
# Eval num_timesteps=40000, episode_reward=535.76 +/- 202.22
# Episode length: 1001.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1e+03       |
# |    mean_reward          | 536         |
# | time/                   |             |
# |    total_timesteps      | 40000       |
# | train/                  |             |
# |    approx_kl            | 0.026040057 |
# |    clip_fraction        | 0.0486      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -3.07       |
# |    explained_variance   | 0.112       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0749     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.013      |
# |    std                  | 1.13        |
# |    value_loss           | 0.0839      |
# -----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 215   |
# |    iterations      | 20    |
# |    time_elapsed    | 189   |
# |    total_timesteps | 40960 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 219         |
# |    iterations           | 21          |
# |    time_elapsed         | 196         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.018331356 |
# |    clip_fraction        | 0.0325      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -3.09       |
# |    explained_variance   | 0.127       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0591     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00984    |
# |    std                  | 1.14        |
# |    value_loss           | 0.101       |
# -----------------------------------------
# Eval num_timesteps=45000, episode_reward=566.80 +/- 197.85
# Episode length: 1001.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1e+03       |
# |    mean_reward          | 567         |
# | time/                   |             |
# |    total_timesteps      | 45000       |
# | train/                  |             |
# |    approx_kl            | 0.018006343 |
# |    clip_fraction        | 0.0387      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -3.13       |
# |    explained_variance   | 0.145       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.073      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0103     |
# |    std                  | 1.17        |
# |    value_loss           | 0.12        |
# -----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 214   |
# |    iterations      | 22    |
# |    time_elapsed    | 210   |
# |    total_timesteps | 45056 |
# ------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 217        |
# |    iterations           | 23         |
# |    time_elapsed         | 216        |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.02308248 |
# |    clip_fraction        | 0.0513     |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -3.16      |
# |    explained_variance   | 0.125      |
# |    learning_rate        | 0.0005     |
# |    loss                 | -0.0754    |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.0152    |
# |    std                  | 1.17       |
# |    value_loss           | 0.108      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 220         |
# |    iterations           | 24          |
# |    time_elapsed         | 222         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.019930454 |
# |    clip_fraction        | 0.0309      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -3.17       |
# |    explained_variance   | 0.129       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0783     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00866    |
# |    std                  | 1.18        |
# |    value_loss           | 0.0804      |
# -----------------------------------------
# Eval num_timesteps=50000, episode_reward=429.46 +/- 174.94
# Episode length: 1001.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1e+03       |
# |    mean_reward          | 429         |
# | time/                   |             |
# |    total_timesteps      | 50000       |
# | train/                  |             |
# |    approx_kl            | 0.021986492 |
# |    clip_fraction        | 0.0385      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -3.19       |
# |    explained_variance   | 0.122       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0838     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0129     |
# |    std                  | 1.2         |
# |    value_loss           | 0.0994      |
# -----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 215   |
# |    iterations      | 25    |
# |    time_elapsed    | 237   |
# |    total_timesteps | 51200 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 218         |
# |    iterations           | 26          |
# |    time_elapsed         | 243         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.015458246 |
# |    clip_fraction        | 0.0148      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -3.21       |
# |    explained_variance   | 0.131       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0591     |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00632    |
# |    std                  | 1.21        |
# |    value_loss           | 0.106       |
# -----------------------------------------
# Eval num_timesteps=55000, episode_reward=550.97 +/- 214.66
# Episode length: 1001.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1e+03       |
# |    mean_reward          | 551         |
# | time/                   |             |
# |    total_timesteps      | 55000       |
# | train/                  |             |
# |    approx_kl            | 0.017692814 |
# |    clip_fraction        | 0.0196      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -3.22       |
# |    explained_variance   | 0.123       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0586     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00726    |
# |    std                  | 1.21        |
# |    value_loss           | 0.124       |
# -----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 213   |
# |    iterations      | 27    |
# |    time_elapsed    | 258   |
# |    total_timesteps | 55296 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 216         |
# |    iterations           | 28          |
# |    time_elapsed         | 264         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.017867867 |
# |    clip_fraction        | 0.026       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -3.23       |
# |    explained_variance   | 0.127       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0681     |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0108     |
# |    std                  | 1.22        |
# |    value_loss           | 0.105       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 219         |
# |    iterations           | 29          |
# |    time_elapsed         | 270         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.015793812 |
# |    clip_fraction        | 0.0199      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -3.24       |
# |    explained_variance   | 0.125       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0783     |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00773    |
# |    std                  | 1.23        |
# |    value_loss           | 0.0986      |
# -----------------------------------------
# Eval num_timesteps=60000, episode_reward=466.62 +/- 136.98
# Episode length: 1001.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1e+03       |
# |    mean_reward          | 467         |
# | time/                   |             |
# |    total_timesteps      | 60000       |
# | train/                  |             |
# |    approx_kl            | 0.022478156 |
# |    clip_fraction        | 0.0277      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -3.26       |
# |    explained_variance   | 0.129       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0668     |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0102     |
# |    std                  | 1.24        |
# |    value_loss           | 0.0952      |
# -----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 215   |
# |    iterations      | 30    |
# |    time_elapsed    | 285   |
# |    total_timesteps | 61440 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 217         |
# |    iterations           | 31          |
# |    time_elapsed         | 291         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.019497689 |
# |    clip_fraction        | 0.0347      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -3.27       |
# |    explained_variance   | 0.132       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0854     |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0109     |
# |    std                  | 1.24        |
# |    value_loss           | 0.0966      |
# -----------------------------------------
# Eval num_timesteps=65000, episode_reward=536.81 +/- 168.07
# Episode length: 1001.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1e+03       |
# |    mean_reward          | 537         |
# | time/                   |             |
# |    total_timesteps      | 65000       |
# | train/                  |             |
# |    approx_kl            | 0.014640536 |
# |    clip_fraction        | 0.015       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -3.29       |
# |    explained_variance   | 0.132       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0757     |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00652    |
# |    std                  | 1.26        |
# |    value_loss           | 0.0952      |
# -----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 214   |
# |    iterations      | 32    |
# |    time_elapsed    | 306   |
# |    total_timesteps | 65536 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 216         |
# |    iterations           | 33          |
# |    time_elapsed         | 312         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.015135162 |
# |    clip_fraction        | 0.0194      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -3.31       |
# |    explained_variance   | 0.128       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0834     |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00858    |
# |    std                  | 1.26        |
# |    value_loss           | 0.0876      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 218         |
# |    iterations           | 34          |
# |    time_elapsed         | 318         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.021366745 |
# |    clip_fraction        | 0.0252      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -3.32       |
# |    explained_variance   | 0.134       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0646     |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0117     |
# |    std                  | 1.28        |
# |    value_loss           | 0.0997      |
# -----------------------------------------
# Eval num_timesteps=70000, episode_reward=683.24 +/- 249.97
# Episode length: 1001.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1e+03       |
# |    mean_reward          | 683         |
# | time/                   |             |
# |    total_timesteps      | 70000       |
# | train/                  |             |
# |    approx_kl            | 0.018801395 |
# |    clip_fraction        | 0.0175      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -3.35       |
# |    explained_variance   | 0.141       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0728     |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00842    |
# |    std                  | 1.31        |
# |    value_loss           | 0.105       |
# -----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 215   |
# |    iterations      | 35    |
# |    time_elapsed    | 332   |
# |    total_timesteps | 71680 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 217         |
# |    iterations           | 36          |
# |    time_elapsed         | 339         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.023065075 |
# |    clip_fraction        | 0.0355      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -3.38       |
# |    explained_variance   | 0.133       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0875     |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0112     |
# |    std                  | 1.31        |
# |    value_loss           | 0.0884      |
# -----------------------------------------
# Eval num_timesteps=75000, episode_reward=447.44 +/- 154.40
# Episode length: 1001.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1e+03       |
# |    mean_reward          | 447         |
# | time/                   |             |
# |    total_timesteps      | 75000       |
# | train/                  |             |
# |    approx_kl            | 0.019585757 |
# |    clip_fraction        | 0.0299      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -3.38       |
# |    explained_variance   | 0.145       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0868     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0108     |
# |    std                  | 1.31        |
# |    value_loss           | 0.0932      |
# -----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 214   |
# |    iterations      | 37    |
# |    time_elapsed    | 353   |
# |    total_timesteps | 75776 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 216         |
# |    iterations           | 38          |
# |    time_elapsed         | 360         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.019606957 |
# |    clip_fraction        | 0.0349      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -3.37       |
# |    explained_variance   | 0.121       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0855     |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0101     |
# |    std                  | 1.3         |
# |    value_loss           | 0.0766      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 217         |
# |    iterations           | 39          |
# |    time_elapsed         | 366         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.018193679 |
# |    clip_fraction        | 0.0415      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -3.39       |
# |    explained_variance   | 0.138       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0799     |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0131     |
# |    std                  | 1.33        |
# |    value_loss           | 0.114       |
# -----------------------------------------
# Eval num_timesteps=80000, episode_reward=464.61 +/- 87.59
# Episode length: 1001.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1e+03       |
# |    mean_reward          | 465         |
# | time/                   |             |
# |    total_timesteps      | 80000       |
# | train/                  |             |
# |    approx_kl            | 0.019040607 |
# |    clip_fraction        | 0.0326      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -3.41       |
# |    explained_variance   | 0.14        |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0718     |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00962    |
# |    std                  | 1.34        |
# |    value_loss           | 0.0905      |
# -----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 215   |
# |    iterations      | 40    |
# |    time_elapsed    | 380   |
# |    total_timesteps | 81920 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 216         |
# |    iterations           | 41          |
# |    time_elapsed         | 387         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.018599907 |
# |    clip_fraction        | 0.023       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -3.41       |
# |    explained_variance   | 0.142       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0843     |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00839    |
# |    std                  | 1.33        |
# |    value_loss           | 0.109       |
# -----------------------------------------
# Eval num_timesteps=85000, episode_reward=565.27 +/- 174.12
# Episode length: 1001.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1e+03       |
# |    mean_reward          | 565         |
# | time/                   |             |
# |    total_timesteps      | 85000       |
# | train/                  |             |
# |    approx_kl            | 0.025588598 |
# |    clip_fraction        | 0.0491      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -3.42       |
# |    explained_variance   | 0.128       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0866     |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0133     |
# |    std                  | 1.35        |
# |    value_loss           | 0.0973      |
# -----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 214   |
# |    iterations      | 42    |
# |    time_elapsed    | 401   |
# |    total_timesteps | 86016 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 216         |
# |    iterations           | 43          |
# |    time_elapsed         | 407         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.014762494 |
# |    clip_fraction        | 0.0196      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -3.45       |
# |    explained_variance   | 0.13        |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0839     |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00787    |
# |    std                  | 1.37        |
# |    value_loss           | 0.0924      |
# -----------------------------------------
# Eval num_timesteps=90000, episode_reward=535.12 +/- 157.18
# Episode length: 1001.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1e+03       |
# |    mean_reward          | 535         |
# | time/                   |             |
# |    total_timesteps      | 90000       |
# | train/                  |             |
# |    approx_kl            | 0.021061804 |
# |    clip_fraction        | 0.0291      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -3.46       |
# |    explained_variance   | 0.136       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.087      |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00997    |
# |    std                  | 1.37        |
# |    value_loss           | 0.089       |
# -----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 213   |
# |    iterations      | 44    |
# |    time_elapsed    | 421   |
# |    total_timesteps | 90112 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 215         |
# |    iterations           | 45          |
# |    time_elapsed         | 428         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.019314306 |
# |    clip_fraction        | 0.0319      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -3.47       |
# |    explained_variance   | 0.137       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.076      |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0125     |
# |    std                  | 1.37        |
# |    value_loss           | 0.109       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 216         |
# |    iterations           | 46          |
# |    time_elapsed         | 434         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.027672894 |
# |    clip_fraction        | 0.06        |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -3.47       |
# |    explained_variance   | 0.12        |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0758     |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0146     |
# |    std                  | 1.37        |
# |    value_loss           | 0.0875      |
# -----------------------------------------
# Eval num_timesteps=95000, episode_reward=630.35 +/- 274.58
# Episode length: 1001.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1e+03       |
# |    mean_reward          | 630         |
# | time/                   |             |
# |    total_timesteps      | 95000       |
# | train/                  |             |
# |    approx_kl            | 0.025234662 |
# |    clip_fraction        | 0.0505      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -3.48       |
# |    explained_variance   | 0.127       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0879     |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0153     |
# |    std                  | 1.38        |
# |    value_loss           | 0.0975      |
# -----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 214   |
# |    iterations      | 47    |
# |    time_elapsed    | 448   |
# |    total_timesteps | 96256 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 215         |
# |    iterations           | 48          |
# |    time_elapsed         | 455         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.020160142 |
# |    clip_fraction        | 0.0314      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -3.49       |
# |    explained_variance   | 0.144       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0929     |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0109     |
# |    std                  | 1.39        |
# |    value_loss           | 0.0768      |
# -----------------------------------------
# Eval num_timesteps=100000, episode_reward=392.92 +/- 135.84
# Episode length: 1001.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1e+03       |
# |    mean_reward          | 393         |
# | time/                   |             |
# |    total_timesteps      | 100000      |
# | train/                  |             |
# |    approx_kl            | 0.015557397 |
# |    clip_fraction        | 0.0212      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -3.51       |
# |    explained_variance   | 0.131       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.101      |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0084     |
# |    std                  | 1.4         |
# |    value_loss           | 0.096       |
# -----------------------------------------
# -------------------------------
# | time/              |        |
# |    fps             | 213    |
# |    iterations      | 49     |
# |    time_elapsed    | 469    |
# |    total_timesteps | 100352 |
# -------------------------------

# %% [markdown]
# Loss Visualization

# %%
import matplotlib.pyplot as plt
from tensorboard.backend.event_processing import event_accumulator

# Load logs
ea = event_accumulator.EventAccumulator('./ppo_tensorboard_logs/PPO_2/')
ea.Reload()

# Extract scalars
val_loss = ea.Scalars('train/value_loss')
pol_loss = ea.Scalars('train/policy_gradient_loss')
entropy  = ea.Scalars('train/entropy_loss')
eval_rew = ea.Scalars('eval/mean_reward')

# Convert to lists
val_steps, val_vals = zip(*[(x.step, x.value) for x in val_loss])
pol_steps, pol_vals = zip(*[(x.step, x.value) for x in pol_loss])
ent_steps, ent_vals = zip(*[(x.step, x.value) for x in entropy])
eval_steps, eval_vals = zip(*[(x.step, x.value) for x in eval_rew])

# Create figure and subplots
fig, axs = plt.subplots(4, 1, figsize=(14, 12), sharex=True)

# Plot 1: Value Loss
axs[0].plot(val_steps, val_vals, label="Value Loss", color='tab:blue')
axs[0].set_ylabel("Value Loss")
axs[0].legend()
axs[0].grid(True)

# Plot 2: Policy Gradient Loss
axs[1].plot(pol_steps, pol_vals, label="Policy Gradient Loss", color='tab:orange')
axs[1].set_ylabel("Policy Loss")
axs[1].legend()
axs[1].grid(True)

# Plot 3: Entropy Loss
axs[2].plot(ent_steps, ent_vals, label="Entropy Loss", color='tab:green')
axs[2].set_ylabel("Entropy Loss")
axs[2].legend()
axs[2].grid(True)

# Plot 4: Evaluation Reward
axs[3].plot(eval_steps, eval_vals, label="Evaluation Reward", color='tab:red', linestyle='--')
axs[3].set_xlabel("Timesteps")
axs[3].set_ylabel("Eval Reward")
axs[3].legend()
axs[3].grid(True)

# Title & layout
fig.suptitle("PPO Training Metrics Over Time", fontsize=16)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %% [markdown]
# Evaluation

# %%
test_model = PPO.load("../models/dwf_rl_pricing_model_v6.zip")
# Out:
# c:\anaconda\envs\analysis\Lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(

# %%
# === Load dataset ===
test_df = pd.read_csv("../datasets/test_split.csv")

# %%
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
import numpy as np
import pandas as pd

def evaluate_model_on_test(model: PPO, test_df: pd.DataFrame):
    env = RideHailingEnv(test_df.copy())  # use a copy to avoid modifying original
    obs, _ = env.reset()
    
    done = False
    total_cost = 0
    retained_from_cancel = 0
    completed_rides = 0
    original_cancellations = 0
    ride_count = 0
    incentive_total = 0
    fare_adj_total = 0

    while not done:
        row = env.df.iloc[env.current_idx]
        base_fare = row['Base Fare']
        t_i = row['Request to Pickup']
        original_cr = row['CR']  # original cancellation rate before action

        # Count originally cancelled rides
        originally_cancelled = original_cr >= 0.5
        if originally_cancelled:
            original_cancellations += 1

        # Predict action
        action, _ = model.predict(obs, deterministic=True)
        fare_adj = np.clip(action[0], -0.15, 0.15)
        incentive = np.clip(action[1], 0.0, 5.0)

        obs, reward, done, _, info = env.step(action)
        updated_cr = info["CR"]

        # Track completion & intervention success
        ride_completed = updated_cr < 0.5
        if ride_completed:
            completed_rides += 1
        if originally_cancelled and ride_completed:
            retained_from_cancel += 1

        # Track costs
        delta = 0.2 * base_fare
        cost = incentive + abs(fare_adj) * delta
        total_cost += cost
        incentive_total += incentive
        fare_adj_total += abs(fare_adj)
        ride_count += 1

    # Metrics
    avg_cancel_rate = 1 - (completed_rides / ride_count)
    avg_incentive = incentive_total / ride_count
    avg_fare_adj = fare_adj_total / ride_count
    avg_cost_per_retained = total_cost / retained_from_cancel if retained_from_cancel else 0

    print("\n📊 Final Evaluation Results")
    print(f"📉 Avg Cancellation Rate: {avg_cancel_rate:.3f}")
    print(f"💵 Avg Incentive: ${avg_incentive:.2f}")
    print(f"💵 Avg Fare Adj: {avg_fare_adj:.3f}")
    print(f"💰 Avg Cost per Retained Ride: ${avg_cost_per_retained:.2f}")
    print(f"✅ Retained from Cancellation: {retained_from_cancel} out of {original_cancellations}")

# %%
evaluate_model_on_test(test_model, test_df)
# Out:
# 📊 Final Evaluation Results
# 📉 Avg Cancellation Rate: 0.404
# 💵 Avg Incentive: $0.31
# 💵 Avg Fare Adj: 0.147
# 💰 Avg Cost per Retained Ride: $4.25
# ✅ Retained from Cancellation: 162 out of 565
