# %%
# Load Libraries
import gym
from gym import spaces
import pandas as pd
import numpy as np
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
import os

# %%
# Load your CSV
df = pd.read_csv("train_data.csv")

# Add a 'Base Fare' column with realistic values (e.g., $5 to $20)
np.random.seed(42)  # for reproducibility
df['Base Fare'] = np.round(np.random.uniform(5, 20, size=len(df)), 2)

# %%
# Label encode categorical features
df['Time of Day'] = LabelEncoder().fit_transform(df['Time of Day'])
df['Month of Year'] = LabelEncoder().fit_transform(df['Month of Year'])
df['Pickup Location'] = LabelEncoder().fit_transform(df['Pickup Location'])

print("Dataset loaded and encoded.")
print(df.head())
# Out:
# Dataset loaded and encoded.
#    Pickup Location  Request to Pickup  Hour of Day  Time of Day  \
# 0               29              327.0           16            0
# 1              187              253.0            8            2
# 2               33              336.0           13            0
# 3              178              102.0           13            0
# 4              129              473.0            4            3
#
#    Month of Year  Surge Pricing Indicator  DWF Reward Applied  \
# 0             11                        0                0.00
# 1              7                        1                0.00
# 2              5                        0                0.00
# 3              6                        0                0.00
# 4              3                        0                3.76
#
#    Historical Demand Forecast       RPI  incentive  fare_adjustment       DPI  \
# 0                    0.373889  0.257379   3.530438        -0.112454  0.017936
# 1                    0.660807  0.560502   4.777390         0.101010  0.000117
# 2                    0.368526  0.363822   1.258762        -0.107803  0.059585
# 3                    0.310974  0.963385   3.681251         0.068923  0.040906
# 4                    0.118151  0.145552   0.888708         0.054046  0.000000
#
#          CR  Base Fare
# 0  0.567685      10.62
# 1  0.506055      19.26
# 2  0.540973      15.98
# 3  0.411931      13.98
# 4  0.599879       7.34

# %%
class RideHailingEnv(gym.Env):
    def __init__(self, df):
        super(RideHailingEnv, self).__init__()
        self.df = df.reset_index(drop=True)
        self.current_idx = 0

        # Normalized 8-D state vector
        self.observation_space = spaces.Box(low=0, high=1, shape=(8,), dtype=np.float32)

        # Action: [fare_adjustment %, rider_incentive $]
        self.action_space = spaces.Box(
            low=np.array([-0.15, 0.0]),
            high=np.array([0.15, 5.0]),
            dtype=np.float32
        )

    def reset(self):
        self.current_idx = 0
        return self._get_observation()

    def step(self, action):
        if self.current_idx >= len(self.df) - 1:
            return self._get_observation(), 0.0, True, {}

        # Extract current ride
        row = self.df.iloc[self.current_idx]

        # Parse action components
        fare_adjustment, rider_incentive = action
        fare_adjustment = np.clip(fare_adjustment, -0.15, 0.15)
        rider_incentive = np.clip(rider_incentive, 0.0, 5.0)

        # Simulated outcome logic
        ride_completed = row['CR'] < 0.5  # Simplified rule based on synthetic CR

        # Cost-aware reward function
        base_fare = 10.0
        base_fare = row['Base Fare'] if 'Base Fare' in row else 10.0  # fallback
        delta = 0.2 * base_fare  # scaling for fare adjustment
        beta = 2.0               # fixed penalty for cancellation

        reward = -(rider_incentive + fare_adjustment * delta)
        if not ride_completed:
            reward -= beta

        self.current_idx += 1
        done = self.current_idx >= len(self.df)

        return self._get_observation(), reward, done, {}

    def _get_observation(self):
        if self.current_idx >= len(self.df): 
            return np.zeros(self.observation_space.shape, dtype=np.float32)

        row = self.df.iloc[self.current_idx]
        return np.array([
            row['Pickup Location'],
            row['Request to Pickup'],
            row['Time of Day'],
            row['Month of Year'],
            row['RPI'],
            row['DPI'],
            row['CR'],
            row['Historical Demand Forecast']
        ], dtype=np.float32)

    

#     # Retrain Model with Updated Observation Space (8 features)
# policy_kwargs = dict(net_arch=[64, 64])
# env = DummyVecEnv([lambda: RideHailingEnv(df)])
# model = PPO("MlpPolicy", env, verbose=1, policy_kwargs=policy_kwargs)

# # ⏱Increase Training Time
# model.learn(total_timesteps=400000)  # More steps = better convergence

# # Save as new version
# model.save("dwf_rl_pricing_model_v6")  # Updated version aligned with your final env

# %%
import gym
import numpy as np
from gym import spaces

class RideHailingEnv_Baseline(gym.Env):
    def __init__(self, df):
        super(RideHailingEnv_Baseline, self).__init__()
        self.df = df.reset_index(drop=True)
        self.current_idx = 0

        # Observation: 4 basic context features
        self.observation_space = spaces.Box(low=0, high=1, shape=(4,), dtype=np.float32)
        self.action_space = spaces.Box(low=np.array([-0.15, 0.0]), high=np.array([0.15, 5.0]), dtype=np.float32)

    def reset(self):
        self.current_idx = 0
        return self._get_observation()

    def step(self, action):
        if self.current_idx >= len(self.df) - 1:
            return self._get_observation(), 0.0, True, {}

        row = self.df.iloc[self.current_idx]
        fare_adjustment, rider_incentive = action

        # --- Basic dynamic cancellation logic ---
        prob_cancel = row['CR']
        if rider_incentive > 2.5:
            prob_cancel *= 0.7
        if fare_adjustment > 0.1:
            prob_cancel *= 0.8

        cancelled = np.random.rand() < prob_cancel
        reward = 1.0 if not cancelled else -1.0

        self.current_idx += 1
        done = self.current_idx >= len(self.df)
        return self._get_observation(), reward, done, {}

    def _get_observation(self):
        if self.current_idx >= len(self.df): 
            return np.zeros(self.observation_space.shape, dtype=np.float32)

        row = self.df.iloc[self.current_idx]
        return np.array([
            row['Pickup Location'],
            row['Request to Pickup'],
            row['Time of Day'],
            row['Month of Year']
        ], dtype=np.float32)


# env = DummyVecEnv([lambda: RideHailingEnv_Baseline(df)])
# model = PPO("MlpPolicy", env, verbose=1, policy_kwargs=policy_kwargs)
# model.learn(total_timesteps=400000)
# model.save("dwf_rl_baseline_model")

# %%
# === Load dataset ===
df = pd.read_csv("test_data.csv")

# %%
np.random.seed(43)  # for reproducibility
df['Base_Fare'] = np.round(np.random.uniform(5, 20, size=len(df)), 2)

# %%
from sklearn.preprocessing import LabelEncoder

# Encode only if not already encoded
if df['Time of Day'].dtype == 'object':
    df['Time of Day'] = LabelEncoder().fit_transform(df['Time of Day'])

if df['Month of Year'].dtype == 'object':
    df['Month of Year'] = LabelEncoder().fit_transform(df['Month of Year'])

if df['Pickup Location'].dtype == 'object':
    df['Pickup Location'] = LabelEncoder().fit_transform(df['Pickup Location'])

# %%
from stable_baselines3 import PPO
import pandas as pd
import numpy as np


# === Load the trained PPO model ===
model = PPO.load("dwf_rl_baseline_model.zip")

# === Create the environment ===
env = RideHailingEnv_Baseline(df.copy())  # or RideHailingEnv_Baseline

base_fare = env.df.iloc[env.current_idx]["Base_Fare"]

# === Run the model over the dataset and collect actions ===
incentives = 0
fare_adjustments = 0
completions = 0

obs = env.reset()
done = False

while not done:
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, done, info = env.step(action)
    print(f"Obs: {obs}")
    print(f"Action: {action}")
    print(f"Reward: {reward}")

    incentives = incentives + base_fare*action[0]
    fare_adjustments = fare_adjustments + action[1]
   
average_incentive = np.mean(incentives)
average_discount = np.mean(fare_adjustments)


# === Print Summary ===
print(f"\n📊 Evaluation Results:")
print(f"✅ Avg Incentive: ${average_incentive:.2f}")
print(f"✅ Avg Discount: ${average_discount:.2f}")
# Out:
# Obs: [ 42. 505.   3.   1.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 74. 419.   2.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [161. 141.   3.   6.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [219. 233.   0.   6.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [132. 274.   3.   1.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [106. 169.   3.   4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [162. 148.   2.   6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 229. -614.    1.   11.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [247. 318.   2.  12.]
# Action: [-0.15  0.  ]
# Reward: -1.0
# Obs: [129. 130.   0.   1.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [236. 238.   0.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [235. 453.   3.   4.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [227. 195.   2.   2.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [145. 203.   1.   1.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [262. 279.   1.   7.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 25. 260.   3.   3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [170. 180.   2.   7.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [162. 308.   3.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [190. 270.   0.   6.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [107. 275.   3.   1.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [127. 137.   0.   4.]
# Action: [0.15       0.01256791]
# Reward: -1.0
# Obs: [ 36. 295.   3.  11.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 1.980e+02 -1.106e+03  1.000e+00  1.000e+00]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [136. 155.   2.   6.]
# Action: [-0.15  0.  ]
# Reward: 1.0
# Obs: [167. 359.   0.   9.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 25. 532.   3.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [233. 148.   3.  11.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 159. 1068.    2.    9.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [230. 503.   2.   4.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [41. 77.  0.  2.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [239. 248.   3.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 80. 798.   3.   3.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 97. 272.   0.   7.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [142. 180.   3.   1.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [181. 392.   3.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [162. 187.   2.   1.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 75. 172.   3.   3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 132. 1216.    2.    4.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [  3. 295.   2.   7.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [216. 229.   3.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [171. 343.   3.   4.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [170. 428.   3.   3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 61. 345.   0.   6.]
# Action: [0.15       0.01708412]
# Reward: -1.0
# Obs: [ 35. 187.   1.   1.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [216.  64.   2.  10.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [170. 230.   0.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [263. 175.   1.   1.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [238. 322.   3.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [130. 229.   2.   9.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [215. 267.   0.   7.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 61. 332.   1.  11.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [244. 259.   3.   6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [146. 141.   0.   9.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [156. 362.   0.   1.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [169. 200.   3.   4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [234.  74.   3.  12.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [243. 286.   3.   6.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 87. 334.   1.   6.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [255. 218.   1.   2.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [107. 180.   3.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [225. 128.   3.  11.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [185.  98.   2.   4.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [  7. 232.   2.   3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [130. 506.   3.   3.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [230. 482.   3.   1.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [238. 274.   3.   6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [186. 216.   0.  11.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 92. 711.   1.  12.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 76. 158.   3.   5.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [142. 151.   3.   2.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [164. 163.   2.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [212. 139.   3.   4.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 73. 487.   2.   6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [114. 182.   0.   1.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [230. 502.   3.   7.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 87. 216.   0.   6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [226. 108.   3.   3.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 61. 241.   3.   9.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 14. 207.   3.   9.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 41. 176.   1.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 40. 137.   2.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [164. 170.   2.   4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [161. 248.   0.   4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [100. 305.   3.  12.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [188. 441.   3.   6.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [167. 275.   0.   6.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [138. 630.   3.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [231. 301.   3.   7.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [181. 149.   0.   6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [226. 567.   0.  12.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [247. 573.   0.   6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [246. 226.   3.   6.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [215. 403.   3.   6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [246. 194.   0.   9.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 74. 242.   3.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [210. 945.   2.  12.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 13. 143.   3.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [228. 157.   2.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [80. 93.  3.  9.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [260. 151.   0.   4.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 79. 128.   3.   1.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [216. 322.   3.   9.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 88. 327.   0.   6.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [130. 169.   0.   1.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [132. 168.   0.   7.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [112. 428.   2.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [182. 180.   3.   3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [170. 283.   0.   9.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [211. 394.   3.   7.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 48. 338.   0.   2.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [155. 487.   0.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [246. 220.   1.   3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [159. 383.   1.   6.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 73. 223.   2.   6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [249.  90.   1.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [107. 370.   1.   5.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [234. 114.   0.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [123. 182.   2.   1.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [238. 263.   0.   5.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 49. 129.   1.   7.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 67. 389.   0.   6.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 28. 235.   0.   4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 41. 248.   3.  11.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 33. 169.   3.   2.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 41. 271.   0.   4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 35. 726.   2.   2.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 15. 927.   2.   1.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [181. 157.   1.   2.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [138. 540.   2.   4.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [203. 225.   3.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [143. 118.   2.   2.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [233. 414.   3.   4.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [216. 115.   1.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 61. 197.   3.   4.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [255. 143.   3.   2.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [249. 118.   2.   7.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [262.  90.   2.   6.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 26. 355.   3.  10.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 47. 355.   3.  11.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [220. 157.   1.   4.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 49. 270.   0.   9.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 40. 134.   2.   6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 97. 234.   2.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [227. 358.   2.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 48. 270.   1.   3.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [256. 148.   0.   7.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [113. 327.   0.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 23. 261.   3.   6.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [256. 360.   3.   6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [181. 230.   0.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 80. 593.   2.   4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [244. 212.   0.   3.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [135. 192.   1.   2.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 47. 282.   2.   3.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [  7. 197.   0.  12.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 74. 448.   2.   4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [  68. -394.    0.    4.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [247. 286.   2.   1.]
# Action: [-0.15  0.  ]
# Reward: 1.0
# Obs: [  32. -573.    2.    4.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [125. 175.   0.   2.]
# Action: [-0.15  0.  ]
# Reward: -1.0
# Obs: [ 41. 270.   2.   1.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [162. 271.   3.   6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [231. 179.   3.  10.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [  4. 257.   2.   3.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 82. 273.   0.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [107. 335.   1.   4.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [127. 428.   0.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 132. 1048.    3.    8.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 23. 224.   0.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [168. 419.   2.   2.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [100. 167.   1.  12.]
# Action: [0.15       0.01719254]
# Reward: -1.0
# Obs: [210. 145.   3.   1.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [188. 125.   3.   3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [237. 340.   2.   9.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [249.  37.   0.   4.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 79. 232.   2.  12.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 50. 372.   1.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [234. 403.   2.   1.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [181. 284.   1.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 88. 237.   3.   2.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [166. 119.   1.   6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [216. 141.   0.   2.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [186. 330.   2.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [224. 205.   2.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [148. 273.   1.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 92. 294.   0.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 71. 191.   0.   9.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [181. 340.   2.   5.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [164.  76.   2.  11.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 61. 219.   0.  12.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 92. 433.   3.   3.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 76. 256.   1.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [249. 252.   2.   4.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [261. 834.   3.   3.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [168. 217.   0.   2.]
# Action: [0.15       0.02291284]
# Reward: -1.0
# Obs: [141. 144.   0.  11.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [254. 171.   0.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 94. 205.   1.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 35. 447.   3.   6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [161. 187.   3.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 82. 323.   1.   2.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [255. 318.   3.   1.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [163. 485.   1.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [132. 156.   2.   3.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 74. 253.   3.   9.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [  7. 270.   2.   3.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [225. 363.   0.   1.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [231. 173.   3.   4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [185.  64.   3.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [138. 323.   2.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 48. 193.   2.   8.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [188. 247.   1.   6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [48. 82.  2.  1.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [114. 200.   2.   9.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [195. 187.   2.   1.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [145. 358.   3.   6.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [210. 375.   0.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [130. 338.   3.   7.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [174. 119.   0.   2.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [237. 379.   2.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [236. 371.   0.   3.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 90. 126.   0.   7.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [161. 287.   2.   7.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 79. 113.   1.   3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 37. 265.   2.  11.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [237. 334.   0.  12.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [149. 471.   3.   4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [  97. 1512.    0.    9.]
# Action: [0.15       0.00581498]
# Reward: 1.0
# Obs: [132. 226.   1.  12.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [183. 282.   0.  10.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 41. 418.   3.   4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [232. 623.   3.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [107. 714.   3.   2.]
# Action: [0.15       0.00969448]
# Reward: 1.0
# Obs: [231. 721.   1.   2.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [129. 120.   0.   4.]
# Action: [0.15       0.02298309]
# Reward: -1.0
# Obs: [ 75. 398.   1.   3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [132.  38.   0.   6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 245. -646.    2.    7.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 69. 438.   0.   7.]
# Action: [-0.15  0.  ]
# Reward: -1.0
# Obs: [246. 251.   0.   2.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 39. 167.   3.   2.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 33. 499.   1.   6.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 213. 1207.    0.    5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [204. 292.   2.  11.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [255. 123.   1.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [246. 459.   3.   4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 61. 209.   3.   9.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [164. 144.   3.   9.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 68. 218.   3.   7.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [168. 199.   1.   3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [145. 375.   3.   7.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [198. 270.   3.   7.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [212. 293.   0.   5.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [233. 280.   2.   3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 72. 365.   3.   8.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [198. 359.   2.   1.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [80. 67.  3.  2.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 68. 324.   0.   6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [138. 456.   1.   3.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [216. 315.   3.   7.]
# Action: [0.15       0.01244536]
# Reward: 1.0
# Obs: [ 61. 694.   2.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 69. 167.   2.   1.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 67. 270.   2.  11.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [234. 459.   3.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [247. 217.   3.   3.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 37. 309.   3.  10.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [136. 280.   1.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 87. 168.   0.   6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [138. 437.   2.   1.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [161. 117.   1.  10.]
# Action: [0.15       0.01925751]
# Reward: 1.0
# Obs: [ 78. 301.   3.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 80. 493.   0.   9.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [138. 351.   0.  12.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 48. 842.   0.  12.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 19. 453.   0.   6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 87. 169.   0.   8.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [198.  65.   3.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [167. 336.   2.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [200. 197.   0.   4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [127. 393.   0.   9.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [240. 192.   1.   8.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [170. 131.   2.   4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 73. 268.   2.   6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [244. 191.   0.   6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 74. 258.   3.   7.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [100. 165.   0.   2.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [137. 222.   2.   3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [164. 166.   0.   4.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [112. 442.   2.   5.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [161. 447.   3.  12.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 33. 309.   3.   4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [245. 874.   2.  12.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 14. 197.   2.   2.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [259. 296.   2.   1.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [67. 94.  3.  6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 82. 185.   0.  10.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 13. 271.   0.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 92. 398.   1.  11.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [203. 472.   1.   2.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [211. 138.   3.   3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 48. 374.   3.  12.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 33. 806.   3.   6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [188. 456.   0.   6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 91. 491.   2.   5.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [127. 202.   2.   6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [202. 272.   0.   7.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 76. 113.   3.   3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [162. 336.   1.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [  7. 136.   0.   9.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [258. 235.   0.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [161. 307.   1.   7.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [236. 374.   3.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [141. 443.   3.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [226. 233.   2.   2.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [237. 331.   3.   1.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 60. 381.   1.   4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [185. 231.   1.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 71. 517.   2.   6.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [231. 186.   3.   1.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [244. 425.   1.  10.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 79. 484.   1.  11.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [219. 121.   0.   6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 49. 489.   3.   3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [161.  80.   2.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [123. 222.   3.   6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [241. 174.   2.   6.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 37. 208.   0.   1.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [163. 380.   1.   9.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 76. 192.   3.   8.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 37. 319.   0.   2.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [254. 339.   3.   5.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [179. 160.   3.   4.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [129. 516.   2.   7.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 15. 401.   0.   6.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [2.480e+02 1.214e+03 2.000e+00 1.000e+00]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 79. 172.   0.   8.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [232. 143.   2.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 14. 336.   0.  12.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [116. 209.   0.   1.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 85. 194.   1.  12.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [234. 650.   0.   4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 91. 360.   3.   6.]
# Action: [0.15       0.02290757]
# Reward: -1.0
# Obs: [  50. 1416.    2.   12.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 53. 188.   3.   9.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [129. 286.   1.   6.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 213. 1067.    0.   11.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [163. 144.   1.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [107. 144.   3.   1.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [138. 318.   1.   3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [151. 371.   0.  12.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 47. 240.   3.   4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [143. 218.   0.   1.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [132. 201.   3.   3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [141. 387.   1.   6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [132. 236.   2.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [157. 215.   0.   6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [230. 319.   1.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 68. 111.   2.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [247. 326.   1.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [238. 170.   2.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [157.  65.   3.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [49. 80.  3. 12.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 53. 156.   3.   6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 89. 307.   3.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [256. 220.   1.   4.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [138. 222.   3.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [132. 943.   3.  10.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [225. 118.   3.   3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 80. 479.   3.  11.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [237. 129.   2.   8.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [162.  67.   0.  10.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 92. 175.   3.   1.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 91. 316.   0.   3.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [114. 209.   1.   5.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [112. 246.   1.   4.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 62. 586.   0.   7.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 49. 224.   0.   6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 79. 134.   2.  11.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 92. 481.   3.  10.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [146. 114.   0.   2.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [143. 174.   0.  10.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [258. 259.   2.   1.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 91. 224.   1.   2.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [164. 228.   0.   5.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [237. 163.   3.   1.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [186.  42.   2.   1.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 72. 389.   1.  10.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 32. 316.   2.   7.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [148. 166.   3.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [239. 109.   3.   4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 89. 353.   1.   8.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [114. 252.   1.  12.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [139. 326.   2.   3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [231. 245.   0.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [188.  76.   1.   1.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [225. 303.   3.   3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [246. 337.   1.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 18. 311.   2.   6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [242. 192.   1.   8.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [226. 191.   3.   6.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [177. 329.   0.   4.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [137. 363.   0.  11.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [255. 226.   0.   3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 14. 362.   0.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [159. 232.   2.   6.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 42. 331.   3.   6.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [197. 128.   0.   4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 147. -479.    3.    8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [216. 223.   1.   7.]
# Action: [-0.15  0.  ]
# Reward: 1.0
# Obs: [243.  95.   2.   4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 80. 556.   3.   8.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [150. 243.   3.   3.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [216. 254.   2.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [246. 327.   1.   4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 39. 215.   2.   4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [142. 886.   1.  12.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [145. 119.   1.   1.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [239. 153.   2.   1.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 36. 460.   3.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [113. 129.   2.   3.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [238. 361.   3.   3.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 68. 227.   3.  10.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [239. 263.   0.  11.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 10. 163.   0.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [142. 263.   0.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [234. 135.   0.   2.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [181. 374.   3.  12.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 22. 998.   2.   7.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [249. 216.   2.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 132. 1236.    3.    9.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 17. 265.   3.  12.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 76. 192.   1.   3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 68. 232.   2.  12.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 78. 635.   3.  12.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [72. 59.  2. 11.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [141. 292.   0.   4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [112. 369.   3.   3.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [255. 741.   3.   3.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [170. 184.   2.   3.]
# Action: [0.15       0.02298069]
# Reward: -1.0
# Obs: [206. 375.   3.   4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [161. 361.   0.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 66. 239.   0.   7.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [250. 272.   2.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [223. 224.   1.   7.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [148. 200.   3.   3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 36. 638.   3.   8.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [145. 216.   1.   7.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [238. 199.   1.  11.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [228. 164.   2.   7.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [196. 115.   2.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [247. 401.   3.   2.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [254. 291.   0.   3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 20. 423.   0.   9.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 61. 318.   2.   1.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 88. 516.   3.   8.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 33. 187.   3.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 42. 182.   2.  12.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 55. 641.   3.   7.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 11. 547.   3.   3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [263. 166.   2.   1.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [138. 209.   3.   6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 7. 99.  3.  4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 74. 441.   3.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [179. 177.   3.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [177. 267.   3.   3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 68. 292.   0.   2.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 13. 215.   0.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 42. 253.   3.   5.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 60. 289.   3.   2.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [231. 115.   0.   6.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 77. 238.   3.   3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [188. 319.   3.   6.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 79. 395.   3.   7.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [128. 254.   3.   6.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 71. 404.   2.   2.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 39. 508.   3.  12.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [198. 146.   3.   6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [125.  48.   0.   8.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [247. 381.   3.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [138. 436.   3.  10.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [  7. 163.   2.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [162. 516.   1.   8.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [227. 379.   0.  10.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [211. 340.   0.   3.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [143. 196.   1.   1.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [255.  88.   2.   1.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [49. 81.  2.  6.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 39. 323.   3.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [225. 152.   0.   6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [246. 175.   3.   6.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 17. 570.   0.   7.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 53. 115.   1.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [220. 268.   2.   2.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [129. 382.   3.  10.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [186. 788.   3.   4.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [125. 189.   0.   1.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [114. 357.   1.   2.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [258. 191.   2.   4.]
# Action: [0.15       0.01718486]
# Reward: 1.0
# Obs: [  7. 395.   0.   6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [  7. 184.   2.   2.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [247. 169.   0.   8.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 51. 149.   0.   6.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [224. 532.   0.   6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [168. 312.   2.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 74. 245.   3.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [132. 207.   2.   5.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 53. 234.   3.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [170. 473.   0.   5.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [247. 346.   3.   8.]
# Action: [0.15       0.01640896]
# Reward: 1.0
# Obs: [ 76. 494.   3.   4.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [234. 106.   2.   2.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [  61. -512.    2.    4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [162. 137.   2.   3.]
# Action: [-0.15  0.  ]
# Reward: -1.0
# Obs: [132. 233.   3.   7.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [198. 185.   1.  11.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [234. 135.   0.  12.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [188. 223.   2.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [170. 202.   3.   6.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 41. 128.   3.   2.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 25. 150.   1.   4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [112.  72.   3.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [223. 358.   1.   2.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [127. 244.   1.   9.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [161. 112.   3.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 91. 328.   3.   6.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [206. 266.   0.   6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [139. 239.   0.   3.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [134.  90.   3.   6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [263. 486.   2.   6.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [112. 202.   3.   4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [162. 207.   1.   6.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [234. 204.   3.   3.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 50. 180.   2.  11.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 11. 206.   2.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 10. 231.   1.   4.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [181.  96.   2.   7.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [137.  90.   3.   4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [133.  56.   0.  10.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 37. 137.   3.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [255. 215.   3.   1.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [126. 212.   0.   1.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [262. 153.   0.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [181. 145.   0.   4.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 81. 251.   0.   5.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 89. 223.   0.   1.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 83. 190.   1.   6.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 79. 192.   3.   9.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [106. 222.   3.   3.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [107. 128.   2.   1.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [148. 866.   3.   9.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [228. 168.   2.  11.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [147. 104.   1.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 89. 468.   3.   3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [254. 373.   3.   2.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 51. 169.   2.   2.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [239. 113.   0.   9.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [163. 197.   1.   2.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [216. 108.   2.  10.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [161. 286.   3.  10.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [130. 276.   2.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 29. 267.   3.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 51. 372.   3.   4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [256. 104.   2.   8.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 20. 107.   1.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [263. 120.   1.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 14. 343.   3.   3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [161. 392.   0.   6.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [207. 250.   3.   8.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [170. 231.   3.   9.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 17. 105.   1.   4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [135. 275.   0.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [167. 166.   3.   6.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [100.  73.   2.   1.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 79. 212.   3.   1.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [48. 52.  2.  3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [42. 98.  3.  3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [152. 469.   3.   6.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 35. 278.   0.   7.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 89. 203.   3.   3.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [168. 163.   0.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [255. 216.   3.   3.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [139. 319.   3.   5.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 65. 464.   3.   6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [141. 157.   1.   1.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [254. 186.   1.   5.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 42. 304.   3.   7.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [232. 136.   3.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [165. 236.   1.   1.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 88. 211.   1.   3.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [216. 257.   2.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 74. 256.   2.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 74. 149.   1.   2.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [164. 233.   3.   6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 61. 222.   0.   6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 70. 121.   2.   3.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [138. 325.   3.   9.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [63. 97.  3.  5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 42. 373.   3.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [181. 412.   3.   5.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 36. 214.   3.   6.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [142. 268.   1.   5.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [145.  82.   1.   4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [209. 398.   3.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 48. 483.   1.   1.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [205. 132.   3.   8.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [230. 359.   3.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [138. 378.   1.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [68. 83.  2.  3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [  7. 162.   3.   5.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 71. 472.   1.   7.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [158.  97.   3.  12.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [256. 168.   3.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 92. 258.   1.  10.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [186. 707.   0.   4.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 98. 113.   2.   7.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [132. 862.   3.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [237.  54.   3.  10.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [112.  88.   3.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [155. 234.   1.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 71. 288.   3.   2.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [132. 269.   0.  10.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 88. 391.   2.   7.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [144. 493.   1.   6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [132. 259.   2.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [174. 276.   3.   4.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [228. 265.   3.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [172. 171.   2.  11.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [102. 308.   0.  12.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [234. 294.   3.   2.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [145. 177.   0.   8.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 36. 653.   2.   5.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 36. 149.   3.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [197. 179.   2.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 25. 141.   2.   6.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 48. 323.   2.   1.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [242. 406.   1.   4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 79. 201.   1.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [243. 353.   2.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [261. 166.   3.   5.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [164. 356.   0.   4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [231. 256.   3.   6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [112. 348.   3.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 61. 170.   0.   6.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 60. 456.   3.   1.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 13. 334.   2.   8.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [  7. 255.   1.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [129. 314.   3.   4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [239. 227.   0.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [261. 188.   2.   4.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 91. 290.   2.   4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 42. 271.   1.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 74. 377.   2.   5.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [125. 189.   2.  11.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [197. 284.   1.   7.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [156. 346.   3.   1.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [138. 472.   3.   6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [227. 588.   2.   2.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [224. 187.   0.   6.]
# Action: [0.15       0.02293764]
# Reward: -1.0
# Obs: [145. 401.   3.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [100. 210.   2.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [256. 477.   0.   6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [  72. -577.    0.    3.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 48. 401.   3.   6.]
# Action: [-0.15  0.  ]
# Reward: -1.0
# Obs: [211. 438.   1.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 17. 169.   0.   1.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 80. 302.   3.   8.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [234. 325.   3.   2.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 42. 130.   2.   6.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [161. 254.   3.   7.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [186. 439.   0.  10.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [209. 222.   0.   3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 51. 865.   0.   6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [186. 181.   2.   4.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [234.  95.   2.   2.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 77. 394.   0.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 67. 381.   0.  12.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [249. 334.   3.   3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [234. 240.   0.   9.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [225. 240.   3.   2.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [189. 392.   2.   6.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [106. 277.   1.  11.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [215. 126.   1.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 68. 442.   1.   2.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 75. 314.   3.   4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [121. 269.   3.   8.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [130. 502.   3.   4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [164. 286.   0.   2.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [148. 153.   0.   3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 39. 416.   2.   4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [168. 257.   2.   1.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 52. 684.   3.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 143. -548.    2.   11.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 72. 191.   2.  12.]
# Action: [-0.15  0.  ]
# Reward: 1.0
# Obs: [224. 230.   1.   5.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [230. 132.   0.   8.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [  7. 351.   0.   1.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [235. 187.   3.   2.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 76. 164.   2.   9.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [211. 274.   3.   9.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [181. 374.   1.   9.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [179. 259.   0.   4.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [230. 222.   3.   7.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [206.  70.   2.   9.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 74. 245.   2.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 39. 391.   0.   1.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 23. 151.   0.   8.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [158. 455.   3.  12.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 79. 108.   3.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [145. 302.   3.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [137. 202.   3.   3.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [218. 272.   2.   9.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [168. 100.   1.   4.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [236. 406.   3.   6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [158. 311.   3.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [216. 222.   2.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [180. 332.   3.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [114. 200.   0.   3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 81. 306.   0.   1.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [123.  88.   1.  10.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [234. 150.   3.   8.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [143. 268.   0.   4.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 48. 336.   3.   5.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [260. 507.   0.   4.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 75. 316.   2.  10.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 74. 454.   2.   5.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [126. 378.   3.   3.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [242. 425.   3.   4.]
# Action: [0.15      0.0088064]
# Reward: 1.0
# Obs: [258. 483.   2.   9.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [119. 244.   0.   5.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 78. 184.   1.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 86. 344.   3.   3.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [126. 347.   0.   8.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 75. 473.   2.   5.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [124. 253.   1.   4.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [130. 208.   3.   2.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [132. 379.   3.   1.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 78. 250.   0.   3.]
# Action: [0.15       0.02118823]
# Reward: -1.0
# Obs: [ 21. 104.   1.  11.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [252. 163.   0.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 20. 130.   3.  12.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 68. 140.   3.   3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [186. 137.   3.   4.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 80. 364.   3.   3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [169. 176.   0.   6.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 14. 240.   3.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [230.  89.   3.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [87. 99.  2.  4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 78. 148.   3.   5.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [246. 369.   2.   2.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [100. 333.   3.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 81. 200.   1.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 11. 463.   0.   9.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [230. 134.   2.   1.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [242.  84.   3.   2.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [249. 474.   2.  10.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [163. 131.   0.   1.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 22. 260.   3.   6.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [138. 696.   3.   6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [196. 188.   1.   4.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 90. 355.   3.   4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 71. 112.   3.   4.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 87. 392.   1.   4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [208. 136.   1.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 55. 280.   2.   5.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [219. 304.   3.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [181. 169.   0.   2.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [116. 326.   2.  10.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [141. 113.   3.   1.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 62. 344.   2.   9.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [162. 114.   0.   2.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 37. 410.   2.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 87. 340.   1.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 76. 249.   3.  10.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 14. 365.   0.   8.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [188. 344.   3.   7.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [181. 133.   0.   8.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [160. 158.   0.   9.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [218. 583.   2.   6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [230. 366.   3.   3.]
# Action: [0.15       0.01638063]
# Reward: -1.0
# Obs: [ 76. 306.   3.   9.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [  4. 277.   1.   1.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 25. 156.   0.   3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [211. 460.   3.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 82. 178.   3.   6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 88. 244.   2.   1.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [132. 575.   3.  10.]
# Action: [0.15       0.01319911]
# Reward: 1.0
# Obs: [132. 314.   0.   4.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [181. 355.   0.   1.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [142. 328.   3.   1.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [239. 325.   2.   3.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [145. 245.   3.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [232. 304.   3.   2.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 37. 313.   2.   6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [161.  99.   0.  12.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [116. 146.   1.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [241. 326.   3.   2.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [141. 326.   3.   3.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 25. 331.   2.  11.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [234. 237.   2.   7.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 63. 249.   1.  10.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [138. 317.   2.   5.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [163. 210.   2.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 61. 413.   0.   4.]
# Action: [0.15 0.  ]
# ...
# Obs: [113. 303.   2.   2.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [   7. -488.    1.    8.]
# Action: [0.15       0.01550202]
# Reward: -1.0
# Obs: [127. 281.   3.   5.]
# Action: [-0.15        0.24577793]
# Reward: -1.0
# Obs: [ 51. 195.   0.   6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [125. 154.   3.   3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 90. 483.   1.   5.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 96. 237.   1.   6.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [193. 278.   0.  11.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 25. 410.   3.  10.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [130. 175.   2.   8.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [164.  83.   3.   8.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [263. 350.   3.  12.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 55. 340.   3.  12.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 61. 662.   1.   3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 43. 190.   2.   4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 69. 473.   3.  10.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [132. 360.   3.   6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 60. 201.   0.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 13. 138.   0.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 32. 201.   0.  12.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [116. 171.   3.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [166. 266.   3.   9.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [170. 283.   1.   5.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [224. 232.   1.   1.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 79. 364.   1.   1.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [162. 266.   2.  12.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 82. 362.   3.   5.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 82. 452.   0.   6.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [129. 202.   3.   1.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 80. 145.   0.   3.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [  7. 206.   2.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [216. 213.   0.  10.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [237.  84.   1.   4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [155. 227.   0.   4.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [162. 302.   3.   3.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [256. 255.   0.   2.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 12. 587.   0.   1.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [226. 288.   0.   6.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [130. 254.   0.   6.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 76. 329.   2.   8.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 17. 788.   3.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [169. 324.   3.   4.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [142.  77.   3.   5.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [  36. 2815.    3.    4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [237. 431.   3.   5.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [261. 376.   1.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [212. 392.   2.   3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [163. 346.   0.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [112. 261.   1.   2.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 14. 190.   0.   6.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [242. 261.   0.   2.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [181. 321.   3.   1.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [234. 155.   0.   1.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 61. 560.   3.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [244. 707.   2.   8.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 50. 120.   1.   1.]
# Action: [0.15       0.01681989]
# Reward: -1.0
# Obs: [ 67. 125.   1.   5.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [239. 156.   0.   1.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [244. 183.   2.   3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 87. 742.   1.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 77. 219.   3.   7.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [148. 228.   3.   4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 40. 116.   2.   8.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [213. 236.   1.   3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 79. 160.   3.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [229. 476.   3.   1.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [225. 236.   0.   3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [123. 246.   2.   5.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [76. 72.  0. 10.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [236. 227.   2.   3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [141. 257.   2.   2.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [112. 130.   1.   2.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [249. 425.   2.   4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [243. 511.   2.   3.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 72. 172.   0.   1.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 75. 334.   1.   2.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [  70. 1229.    3.    3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [100. 208.   3.   4.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [231. 283.   3.   6.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [161. 456.   3.   5.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [209. 216.   1.   3.]
# Action: [0.15       0.00515597]
# Reward: 1.0
# Obs: [223. 210.   3.  10.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [174. 144.   3.   6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 76. 246.   3.  12.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 70. 222.   0.   2.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 29. 224.   3.   8.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [142. 450.   2.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [127. 247.   0.   7.]
# Action: [0.15       0.00049015]
# Reward: -1.0
# Obs: [165. 147.   2.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [142. 164.   2.  12.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [250. 194.   1.   4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [247.  95.   2.   4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [  14. -732.    0.    7.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [117. 234.   0.   2.]
# Action: [-0.15        0.23897547]
# Reward: -1.0
# Obs: [129. 410.   0.   3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [231. 255.   3.   8.]
# Action: [0.15       0.02014627]
# Reward: 1.0
# Obs: [209. 158.   0.   4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [132. 141.   0.   5.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [157. 412.   0.   9.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 41. 215.   3.  12.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [136. 103.   3.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [163. 158.   0.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [140. 159.   2.   2.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [75. 98.  3.  7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [113. 212.   1.  11.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 17. 205.   1.   3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [186. 491.   3.   3.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 87. 285.   0.   4.]
# Action: [0.15      0.0217811]
# Reward: 1.0
# Obs: [230. 553.   3.   3.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [138. 112.   1.   2.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [149. 233.   1.   1.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 161. -415.    1.   11.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [162. 112.   3.   1.]
# Action: [-0.15  0.  ]
# Reward: 1.0
# Obs: [ 62. 560.   2.   6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [  7. 483.   1.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [138. 263.   0.   3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 82. 101.   3.   5.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 80. 432.   0.   1.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 37. 235.   3.  12.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [225. 305.   3.  10.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [229. 170.   3.   3.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [138. 132.   2.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 38. 867.   0.   4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [235. 203.   3.   9.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [48. 74.  2.  6.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [155. 699.   3.   6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [158. 150.   1.   3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 131. -479.    2.   11.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 79. 685.   3.  11.]
# Action: [-0.15  0.  ]
# Reward: -1.0
# Obs: [50. 97.  0.  8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [123. 240.   3.   5.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 35. 229.   3.  11.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 95. 492.   2.   1.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [149. 351.   3.   8.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [210. 120.   0.   2.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 22. 259.   3.   2.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 97. 464.   1.   9.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [138. 151.   2.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 82. 204.   0.   9.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [162. 194.   1.   9.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [215. 433.   2.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [170. 240.   2.   9.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [234. 185.   0.   6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [246. 444.   2.   7.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [132. 644.   0.   9.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [247. 297.   0.   2.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [249. 365.   3.   4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 88. 540.   2.   1.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [142. 852.   3.   3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [213. 211.   3.   1.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [181. 168.   3.   1.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [146. 222.   1.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 41. 168.   3.   2.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 78. 787.   0.   3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [113. 497.   1.   2.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [262. 165.   2.   2.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [144. 424.   3.   2.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [170. 146.   3.   7.]
# Action: [0.15       0.02079331]
# Reward: -1.0
# Obs: [113. 428.   0.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [163.  53.   1.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 14. 380.   2.   1.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [239. 347.   0.   6.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [145. 406.   0.   4.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [164. 481.   1.   4.]
# Action: [0.15      0.0168579]
# Reward: -1.0
# Obs: [ 82. 211.   0.   8.]
# Action: [0.15       0.02099797]
# Reward: -1.0
# Obs: [ 62. 495.   3.   4.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 97. 876.   3.  12.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [151. 196.   2.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [130. 217.   0.   1.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [140. 295.   1.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 100. -409.    2.    4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 41. 379.   0.  10.]
# Action: [-0.15  0.  ]
# Reward: 1.0
# Obs: [138.  80.   1.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 125. -391.    2.    3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [138. 161.   0.   6.]
# Action: [-0.15  0.  ]
# Reward: -1.0
# Obs: [158. 237.   3.   1.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [163. 233.   1.  12.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [107. 169.   3.  11.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [243. 143.   0.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [226. 288.   0.  10.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 17. 221.   0.   6.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 79. 627.   3.   4.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [255. 275.   2.   4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [247. 215.   2.  11.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [225. 145.   0.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [249. 152.   1.   1.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [228. 173.   3.   1.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [130. 373.   3.   4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [116. 174.   1.   6.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 86. 400.   1.  12.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [247. 169.   0.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 79. 694.   3.   9.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [237. 107.   0.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 36. 146.   3.   5.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [164.  60.   0.   3.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [221. 257.   2.   6.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [168. 207.   2.  11.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [164. 587.   3.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [174. 261.   3.   3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 29. 279.   0.   5.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 61. 485.   3.   2.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 50. 479.   2.   6.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [164. 196.   0.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 80. 182.   3.  10.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [156. 151.   0.   4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 40. 184.   2.   1.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 42. 593.   2.  12.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [155. 240.   3.  11.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [230. 298.   2.   3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [160. 397.   0.   9.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 37. 234.   3.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 21. 301.   3.   5.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [215. 181.   0.   3.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [141. 169.   0.   4.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 71. 205.   0.   7.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 37. 306.   3.   9.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 42. 522.   2.  11.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [148. 188.   1.   1.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [135. 146.   2.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [107. 399.   0.  10.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 79. 188.   2.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 81. 258.   3.   6.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [210. 339.   0.   3.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [125. 225.   1.   8.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [158. 157.   3.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [131. 347.   0.   4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [100.  86.   1.   3.]
# Action: [0.15       0.00572948]
# Reward: 1.0
# Obs: [232. 215.   2.  11.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 50. 212.   0.   8.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [241. 606.   0.   1.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 35. 518.   3.   6.]
# Action: [0.15       0.02283978]
# Reward: 1.0
# Obs: [ 91. 167.   2.   3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 70. 293.   1.   3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [181. 214.   2.   6.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [144. 131.   3.   1.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [230. 219.   2.  10.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 41. 446.   2.   3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 88. 792.   3.   6.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 87. 526.   1.   8.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [246. 470.   3.   5.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [187. 201.   0.   6.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 29. 172.   1.  11.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [246. 370.   3.   5.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [161. 153.   0.   2.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 26. 196.   0.   8.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [ 10. 130.   3.   7.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [230. 298.   3.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [239. 181.   0.   4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [122. 101.   0.   8.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 18. 126.   0.   3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [237.  85.   3.   3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [236. 105.   2.   5.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [233. 135.   1.   1.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [138. 321.   0.   7.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [164. 688.   0.   4.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 86. 538.   0.   5.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [212. 369.   1.  10.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [216.  78.   2.   2.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [231. 488.   3.   5.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [246. 403.   3.  10.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [255. 369.   3.   8.]
# Action: [0.15 0.  ]
# Reward: -1.0
# Obs: [244. 191.   0.   1.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [ 21. 151.   2.   3.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [138. 246.   0.   1.]
# Action: [0.15 0.  ]
# Reward: 1.0
# Obs: [138. 246.   0.   1.]
# Action: [0.15 0.  ]
# Reward: 0.0
#
# 📊 Evaluation Results:
# ✅ Avg Incentive: $9844.78
# ✅ Avg Discount: $7.15

# %%
# === Load the trained PPO model ===
model = PPO.load("dwf_rl_pricing_model_v6.zip")

# === Create the environment ===
env = RideHailingEnv(df.copy())  # or RideHailingEnv_Baseline

base_fare = env.df.iloc[env.current_idx]["Base_Fare"]

# === Run the model over the dataset and collect actions ===
incentives = 0
fare_adjustments = 0
completions = 0

obs = env.reset()
done = False

while not done:
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, done, info = env.step(action)

    incentives = incentives + base_fare*action[0]
    fare_adjustments = fare_adjustments + action[1]
   
average_incentive = np.mean(incentives)
average_discount = np.mean(fare_adjustments)


# === Print Summary ===
print(f"\n📊 Evaluation Results:")
print(f"✅ Avg Incentive: ${average_incentive:.2f}")
print(f"✅ Avg Discount: ${average_discount:.2f}")
# Out:
# 📊 Evaluation Results:
# ✅ Avg Incentive: $-10082.80
# ✅ Avg Discount: $0.45
